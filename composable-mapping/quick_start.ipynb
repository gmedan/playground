# %% [markdown]
# # Quick start tutorial
#
# This tutorial only shows the most basic use case on 2D images.

# %%
# !pip install git+https://github.com/honkamj/composable-mapping
# Out:
# Collecting git+https://github.com/honkamj/composable-mapping
#   Cloning https://github.com/honkamj/composable-mapping to /tmp/pip-req-build-feoifb0t
#   Running command git clone --filter=blob:none --quiet https://github.com/honkamj/composable-mapping /tmp/pip-req-build-feoifb0t
#   Resolved https://github.com/honkamj/composable-mapping to commit babd065da3b62a4dd8a8b4a4c96acd57f1e0c549
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.10/dist-packages (from composable-mapping==1.0.0) (2.5.1+cu121)
# Collecting deformation_inversion_layer>=1.1.2 (from composable-mapping==1.0.0)
#   Downloading deformation_inversion_layer-1.1.2-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (from composable-mapping==1.0.0) (5.3.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from composable-mapping==1.0.0) (3.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->composable-mapping==1.0.0) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->composable-mapping==1.0.0) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->composable-mapping==1.0.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->composable-mapping==1.0.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->composable-mapping==1.0.0) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->composable-mapping==1.0.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.0->composable-mapping==1.0.0) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->composable-mapping==1.0.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->composable-mapping==1.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->composable-mapping==1.0.0) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->composable-mapping==1.0.0) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib->composable-mapping==1.0.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->composable-mapping==1.0.0) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->composable-mapping==1.0.0) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->composable-mapping==1.0.0) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->composable-mapping==1.0.0) (2.8.2)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.10/dist-packages (from nibabel->composable-mapping==1.0.0) (6.4.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->composable-mapping==1.0.0) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0->composable-mapping==1.0.0) (3.0.2)
# Downloading deformation_inversion_layer-1.1.2-py3-none-any.whl (12 kB)
# Building wheels for collected packages: composable-mapping
#   Building wheel for composable-mapping (pyproject.toml) ... done
#   Created wheel for composable-mapping: filename=composable_mapping-1.0.0-py3-none-any.whl size=78862 sha256=30fa056b2b4e8666a37257300625a9efe07d841367b3c2d80da57259bbe3d40f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-km6rt61d/wheels/00/ba/a9/c5d9178c190073d4f11656983a9750ca4b1a4c30c6483c4e07
# Successfully built composable-mapping
# Installing collected packages: deformation_inversion_layer, composable-mapping
# Successfully installed composable-mapping-1.0.0 deformation_inversion_layer-1.1.2

# %% [markdown]
# Let us first create a dense deformation and an affine transformation and then compose them.

# %%
import torch
import matplotlib.pyplot as plt

import composable_mapping as cm
from torchvision.transforms import GaussianBlur

coordinate_system = cm.CoordinateSystem.centered_normalized(spatial_shape=(256, 256))
deformation = cm.samplable_volume(
    GaussianBlur(kernel_size=21, sigma=7.0)(20 * torch.randn(1, 2, 256, 256)),
    coordinate_system=coordinate_system,
    data_format=cm.DataFormat.voxel_displacements(),
)
affine = cm.affine(torch.tensor([[0.7, 0.2, 0.0], [0.2, 0.9, 0.0], [0.0, 0.0, 1.0]]))
composition = deformation @ affine
cm.visualize_as_deformed_grid(deformation)
plt.title("Deformation")
plt.show()
cm.visualize_to_as_deformed_grid(affine, target=coordinate_system)
plt.title("Affine")
plt.show()
cm.visualize_as_deformed_grid(composition)
plt.title("Composition")
plt.show()

# %% [markdown]
# Let us apply the composed deformation to an image and visualize the image. The mask of extrapolated regions (shown in red) is automatically generated which can then be used e.g. in loss functions.

# %%
from matplotlib.image import imread

image_data = torch.from_numpy(imread("../tutorials/camera.png"))[None, None]
image_coordinate_system = cm.CoordinateSystem.centered_normalized(
    spatial_shape=image_data.shape[2:],
    voxel_size=(1.0, 1.0)
)
image = cm.samplable_volume(
    image_data,
    coordinate_system=image_coordinate_system,
)
deformed_image = image @ composition

# We flip the coordinates for visualization for the image to show correct size up
visualization_coordinates = image_coordinate_system.transform_world_with_diagonal_matrix(
    torch.tensor([-1.0, 1.0])
)
fig = cm.visualize_to_as_image(image, target=visualization_coordinates)
fig.axes[0].set_title("Original")
plt.show()
fig = cm.visualize_to_as_image(deformed_image, target=visualization_coordinates)
fig.axes[0].set_title("Deformed")
plt.show()
